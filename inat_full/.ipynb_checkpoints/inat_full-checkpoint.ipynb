# %%
import pandas as pd
import re

# %%
df = pd.read_csv("gbif_inat.csv", delimiter=",", low_memory=False)

# %%
df = df.dropna(subset = ['day', 'month', 'year'])

# %%
combined_ymd = df['year'].astype(int).astype(str) + '-' + df['month'].astype(int).astype(str) + '-' + df['day'].astype(int).astype(str)

# %%
# fix_zeroes = re.compile('\d{4}-')
def fix_zeroes(date):
    ymd = date.split('-')
    ans = ""
    ans += ymd[0] + '-'
    if len(ymd[1]) == 1:
        ans += "0"
    ans += ymd[1] + '-'
    if len(ymd[2]) == 1:
        ans += "0"
    ans += ymd[2]
    return ans
combined_ymd = combined_ymd.apply(fix_zeroes)

# %%
eventDate_truncated = df.eventDate.apply(lambda x: str(x).split('T')[0])

# %%
eventDate_truncated.equals(combined_ymd)
# Out:
# True

# %%
df[df['eventDate'] > df['dateIdentified']].eventDate
# Out:
# 215262    2018-09-03T23:00:00Z
# Name: eventDate, dtype: object

# %%
df[df['eventDate']]

# %%
df[df['eventDate'] > df['dateIdentified']].dateIdentified
# Out:
# 215262    2018-09-03T20:20:16Z
# Name: dateIdentified, dtype: object

# %%
df.da

# %%
df.month
# Out:
# 0          NaN
# 1          9.0
# 2          2.0
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          4.0
# 9          4.0
# 10         5.0
# 11         5.0
# 12         NaN
# 13         NaN
# 14         5.0
# 15         NaN
# 16         NaN
# 17         NaN
# 18         6.0
# 19         NaN
# 20         NaN
# 21         NaN
# 22         9.0
# 23         9.0
# 24         9.0
# 25         9.0
# 26         9.0
# 27         9.0
# 28         NaN
# 29         NaN
#           ...
# 1048545    NaN
# 1048546    NaN
# 1048547    NaN
# 1048548    NaN
# 1048549    NaN
# 1048550    NaN
# 1048551    NaN
# 1048552    NaN
# 1048553    NaN
# 1048554    NaN
# 1048555    NaN
# 1048556    NaN
# 1048557    NaN
# 1048558    NaN
# 1048559    NaN
# 1048560    NaN
# 1048561    NaN
# 1048562    NaN
# 1048563    NaN
# 1048564    NaN
# 1048565    NaN
# 1048566    NaN
# 1048567    NaN
# 1048568    NaN
# 1048569    NaN
# 1048570    NaN
# 1048571    NaN
# 1048572    NaN
# 1048573    NaN
# 1048574    NaN
# Name: month, dtype: float64

# %%
df.columns
# Out:
# Index([u'gbifID', u'datasetKey', u'occurrenceID', u'kingdom', u'phylum',
#        u'class', u'order', u'family', u'genus', u'species',
#        u'infraspecificEpithet', u'taxonRank', u'scientificName',
#        u'countryCode', u'locality', u'publishingOrgKey', u'decimalLatitude',
#        u'decimalLongitude', u'coordinateUncertaintyInMeters',
#        u'coordinatePrecision', u'elevation', u'elevationAccuracy', u'depth',
#        u'depthAccuracy', u'eventDate', u'day', u'month', u'year', u'taxonKey',
#        u'speciesKey', u'basisOfRecord', u'institutionCode', u'collectionCode',
#        u'catalogNumber', u'recordNumber', u'identifiedBy', u'dateIdentified',
#        u'license', u'rightsHolder', u'recordedBy', u'typeStatus',
#        u'establishmentMeans', u'lastInterpreted', u'mediaType', u'issue'],
#       dtype='object')

# %%
df.issue.unique()
# Out:
# array([nan, 'GEODETIC_DATUM_ASSUMED_WGS84',
#        'COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84',
#        'COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;TAXON_MATCH_FUZZY',
#        'COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_UNCERTAINTY_METERS_INVALID',
#        'COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;TAXON_MATCH_HIGHERRANK',
#        'COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;INDIVIDUAL_COUNT_INVALID',
#        'GEODETIC_DATUM_ASSUMED_WGS84;TAXON_MATCH_FUZZY',
#        'GEODETIC_DATUM_ASSUMED_WGS84;COUNTRY_DERIVED_FROM_COORDINATES',
#        'GEODETIC_DATUM_ASSUMED_WGS84;TAXON_MATCH_HIGHERRANK;BASIS_OF_RECORD_INVALID',
#        'GEODETIC_DATUM_ASSUMED_WGS84;TAXON_MATCH_HIGHERRANK'], dtype=object)

# %%
df = df.drop(['countryCode','publishingOrgKey','elevationAccuracy', 'depth', 'depthAccuracy',
              'day', 'month', 'year', 'identifiedBy', 'dateIdentified', 'license',
             'recordedBy', 'typeStatus', 'lastInterpreted', 'mediaType'], 1)

# %%
df
# Out:
#              gbifID                            datasetKey  \
# 0        1065564453  66f6192f-6cc0-45fd-a2d1-e76f5ae3eab2
# 1        1065606834  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2        1065607488  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3        1065607634  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4        1065608032  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 5        1065608037  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 6        1065608145  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 7        1065608148  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 8        1913654360  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 9        1913654433  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 10       1913654554  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 11       1913654814  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 12       1913654859  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 13       1913655278  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 14       1913655304  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 15       1913656222  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 16       1913656224  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 17       1913656225  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 18       1913656475  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 19       1913656685  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 20       1913656717  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 21       1913661190  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 22       1913662710  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 23       1913663290  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 24       1913663369  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 25       1913663383  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 26       1913663387  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 27       1913663388  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 28       1913664900  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 29       1913665252  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# ...             ...                                   ...
# 1048545  1360249018  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048546  1360249031  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048547  1360249036  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048548  1360249708  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048549  1360249713  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048550  1360249733  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048551  1360249734  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048552  1360249737  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048553  1360249738  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048554  1360249752  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048555  1360249782  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048556  1360250909  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048557  1360250932  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048558  1360250937  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048559  1360250941  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048560  1360250946  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048561  1360250956  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048562  1360250984  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048563  1360250998  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048564  1360256457  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048565  1360256474  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048566  1360256495  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048567  1360256516  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048568  1360256517  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048569  1360256519  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048570  1360256535  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048571  1360256544  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048572  1360256550  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048573  1360256558  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1048574  1360256566  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
#
#                                               occurrenceID   kingdom  \
# 0                                diveboard:211262_209782_0  Animalia
# 1          http://www.inaturalist.org/observations/1218584   Plantae
# 2          http://www.inaturalist.org/observations/1220290     Fungi
# 3          http://www.inaturalist.org/observations/1220505  Animalia
# 4          http://www.inaturalist.org/observations/1221480  Animalia
# 5          http://www.inaturalist.org/observations/1221479  Animalia
# 6          http://www.inaturalist.org/observations/1221614  Animalia
# 7          http://www.inaturalist.org/observations/1221617  Animalia
# 8        https://www.inaturalist.org/observations/11976556   Plantae
# 9        https://www.inaturalist.org/observations/12079495   Plantae
# 10       https://www.inaturalist.org/observations/12268863   Plantae
# 11       https://www.inaturalist.org/observations/12595466   Plantae
# 12       https://www.inaturalist.org/observations/12647444  Animalia
# 13       https://www.inaturalist.org/observations/13042119  Animalia
# 14       https://www.inaturalist.org/observations/13063800   Plantae
# 15       https://www.inaturalist.org/observations/13863645  Animalia
# 16       https://www.inaturalist.org/observations/13863672  Animalia
# 17       https://www.inaturalist.org/observations/13863673  Animalia
# 18       https://www.inaturalist.org/observations/13970966   Plantae
# 19       https://www.inaturalist.org/observations/14078597  Animalia
# 20       https://www.inaturalist.org/observations/14096621  Animalia
# 21       https://www.inaturalist.org/observations/15821779  Animalia
# 22       https://www.inaturalist.org/observations/16176549   Plantae
# 23       https://www.inaturalist.org/observations/16267759   Plantae
# 24       https://www.inaturalist.org/observations/16276540   Plantae
# 25       https://www.inaturalist.org/observations/16279335   Plantae
# 26       https://www.inaturalist.org/observations/16279353   Plantae
# 27       https://www.inaturalist.org/observations/16279354   Plantae
# 28       https://www.inaturalist.org/observations/16411114  Animalia
# 29       https://www.inaturalist.org/observations/16442073  Animalia
# ...                                                    ...       ...
# 1048545             URN:catalog:CLO:EBIRD_CAN:OBS310688859  Animalia
# 1048546             URN:catalog:CLO:EBIRD_CAN:OBS310688852  Animalia
# 1048547             URN:catalog:CLO:EBIRD_CAN:OBS310688862  Animalia
# 1048548                 URN:catalog:CLO:EBIRD:OBS310681139  Animalia
# 1048549                 URN:catalog:CLO:EBIRD:OBS310681138  Animalia
# 1048550                 URN:catalog:CLO:EBIRD:OBS310685687  Animalia
# 1048551                 URN:catalog:CLO:EBIRD:OBS310681130  Animalia
# 1048552                 URN:catalog:CLO:EBIRD:OBS310681135  Animalia
# 1048553                 URN:catalog:CLO:EBIRD:OBS310681129  Animalia
# 1048554                 URN:catalog:CLO:EBIRD:OBS310681141  Animalia
# 1048555                 URN:catalog:CLO:EBIRD:OBS310681137  Animalia
# 1048556                 URN:catalog:CLO:EBIRD:OBS310681143  Animalia
# 1048557                 URN:catalog:CLO:EBIRD:OBS310681142  Animalia
# 1048558                 URN:catalog:CLO:EBIRD:OBS310681134  Animalia
# 1048559                 URN:catalog:CLO:EBIRD:OBS310681133  Animalia
# 1048560                 URN:catalog:CLO:EBIRD:OBS310681132  Animalia
# 1048561                 URN:catalog:CLO:EBIRD:OBS310779469  Animalia
# 1048562                 URN:catalog:CLO:EBIRD:OBS310681131  Animalia
# 1048563                 URN:catalog:CLO:EBIRD:OBS310681136  Animalia
# 1048564             URN:catalog:CLO:EBIRD_CAN:OBS310582697  Animalia
# 1048565             URN:catalog:CLO:EBIRD_CAN:OBS310582707  Animalia
# 1048566             URN:catalog:CLO:EBIRD_CAN:OBS310582700  Animalia
# 1048567             URN:catalog:CLO:EBIRD_CAN:OBS310582689  Animalia
# 1048568             URN:catalog:CLO:EBIRD_CAN:OBS310582706  Animalia
# 1048569             URN:catalog:CLO:EBIRD_CAN:OBS310582698  Animalia
# 1048570             URN:catalog:CLO:EBIRD_CAN:OBS310582704  Animalia
# 1048571             URN:catalog:CLO:EBIRD_CAN:OBS310582690  Animalia
# 1048572             URN:catalog:CLO:EBIRD_CAN:OBS310582695  Animalia
# 1048573             URN:catalog:CLO:EBIRD_CAN:OBS310582687  Animalia
# 1048574             URN:catalog:CLO:EBIRD_CAN:OBS310582692  Animalia
#
#                 phylum           class            order           family  \
# 0             Chordata  Actinopterygii  Syngnathiformes     Syngnathidae
# 1         Tracheophyta   Magnoliopsida         Ericales        Ericaceae
# 2        Basidiomycota    Dacrymycetes   Dacrymycetales  Dacrymycetaceae
# 3             Chordata            Aves     Anseriformes         Anatidae
# 4             Chordata            Aves     Anseriformes         Anatidae
# 5             Chordata            Aves     Anseriformes         Anatidae
# 6             Chordata            Aves    Passeriformes      Emberizidae
# 7             Chordata            Aves  Charadriiformes          Laridae
# 8         Tracheophyta   Magnoliopsida       Sapindales      Sapindaceae
# 9         Tracheophyta   Magnoliopsida       Sapindales      Sapindaceae
# 10        Tracheophyta       Pinopsida          Pinales         Pinaceae
# 11        Tracheophyta   Magnoliopsida       Sapindales      Sapindaceae
# 12          Arthropoda         Insecta       Coleoptera    Coccinellidae
# 13            Chordata        Amphibia            Anura          Ranidae
# 14        Tracheophyta   Magnoliopsida       Sapindales      Sapindaceae
# 15            Chordata        Reptilia       Testudines         Emydidae
# 16            Chordata        Reptilia       Testudines         Emydidae
# 17            Chordata        Reptilia       Testudines         Emydidae
# 18        Tracheophyta   Magnoliopsida       Dipsacales   Caprifoliaceae
# 19          Arthropoda         Insecta      Lepidoptera        Noctuidae
# 20          Arthropoda         Insecta      Hymenoptera        Siricidae
# 21          Arthropoda         Insecta      Lepidoptera        Noctuidae
# 22        Tracheophyta       Pinopsida          Pinales         Pinaceae
# 23        Tracheophyta      Liliopsida      Alismatales    Juncaginaceae
# 24        Tracheophyta   Magnoliopsida      Nymphaeales     Nymphaeaceae
# 25        Tracheophyta   Magnoliopsida       Sapindales      Sapindaceae
# 26        Tracheophyta   Magnoliopsida       Sapindales      Sapindaceae
# 27        Tracheophyta   Magnoliopsida       Sapindales      Sapindaceae
# 28            Chordata        Amphibia          Caudata   Plethodontidae
# 29          Arthropoda       Arachnida          Araneae        Araneidae
# ...                ...             ...              ...              ...
# 1048545       Chordata            Aves    Passeriformes      Emberizidae
# 1048546       Chordata            Aves    Passeriformes        Parulidae
# 1048547       Chordata            Aves    Passeriformes     Hirundinidae
# 1048548       Chordata            Aves    Passeriformes      Emberizidae
# 1048549       Chordata            Aves    Columbiformes       Columbidae
# 1048550       Chordata            Aves   Pelecaniformes         Ardeidae
# 1048551       Chordata            Aves    Passeriformes         Corvidae
# 1048552       Chordata            Aves    Passeriformes          Paridae
# 1048553       Chordata            Aves       Piciformes          Picidae
# 1048554       Chordata            Aves    Passeriformes     Muscicapidae
# 1048555       Chordata            Aves    Passeriformes      Emberizidae
# 1048556       Chordata            Aves    Passeriformes         Corvidae
# 1048557       Chordata            Aves       Piciformes          Picidae
# 1048558       Chordata            Aves    Passeriformes      Emberizidae
# 1048559       Chordata            Aves    Passeriformes     Fringillidae
# 1048560       Chordata            Aves    Passeriformes         Corvidae
# 1048561       Chordata            Aves    Passeriformes        Parulidae
# 1048562       Chordata            Aves    Passeriformes     Fringillidae
# 1048563       Chordata            Aves    Passeriformes      Emberizidae
# 1048564       Chordata            Aves     Anseriformes         Anatidae
# 1048565       Chordata            Aves  Accipitriformes     Accipitridae
# 1048566       Chordata            Aves     Anseriformes         Anatidae
# 1048567       Chordata            Aves     Anseriformes         Anatidae
# 1048568       Chordata            Aves     Anseriformes         Anatidae
# 1048569       Chordata            Aves   Pelecaniformes         Ardeidae
# 1048570       Chordata            Aves     Anseriformes         Anatidae
# 1048571       Chordata            Aves  Charadriiformes     Scolopacidae
# 1048572       Chordata            Aves     Anseriformes         Anatidae
# 1048573       Chordata            Aves    Passeriformes      Emberizidae
# 1048574       Chordata            Aves    Passeriformes          Paridae
#
#                 genus                   species  \
# 0          Syngnathus  Syngnathus leptorhynchus
# 1          Gaultheria        Gaultheria shallon
# 2          Dacrymyces  Dacrymyces chrysospermus
# 3              Branta         Branta canadensis
# 4                Anas        Anas platyrhynchos
# 5          Lophodytes     Lophodytes cucullatus
# 6           Melospiza         Melospiza melodia
# 7               Larus               Larus canus
# 8                Acer           Acer circinatum
# 9                Acer           Acer circinatum
# 10        Pseudotsuga     Pseudotsuga menziesii
# 11               Acer              Acer negundo
# 12         Coccinella    Coccinella californica
# 13         Lithobates   Lithobates catesbeianus
# 14               Acer       Acer pseudoplatanus
# 15          Chrysemys           Chrysemys picta
# 16          Trachemys         Trachemys scripta
# 17          Trachemys         Trachemys scripta
# 18          Valeriana      Valeriana sitchensis
# 19             Noctua            Noctua pronuba
# 20           Urocerus       Urocerus albicornis
# 21            Dargida        Dargida procinctus
# 22        Pseudotsuga     Pseudotsuga menziesii
# 23         Triglochin       Triglochin maritima
# 24             Nuphar        Nuphar polysepalum
# 25               Acer              Acer glabrum
# 26               Acer           Acer circinatum
# 27               Acer           Acer circinatum
# 28           Ensatina    Ensatina eschscholtzii
# 29            Araneus        Araneus diadematus
# ...               ...                       ...
# 1048545        Pipilo          Pipilo maculatus
# 1048546     Setophaga        Setophaga coronata
# 1048547   Tachycineta    Tachycineta thalassina
# 1048548         Junco            Junco hyemalis
# 1048549  Streptopelia     Streptopelia decaocto
# 1048550         Ardea            Ardea herodias
# 1048551        Corvus              Corvus corax
# 1048552       Poecile      Poecile atricapillus
# 1048553     Dryobates       Dryobates pubescens
# 1048554        Turdus        Turdus migratorius
# 1048555   Zonotrichia   Zonotrichia atricapilla
# 1048556        Corvus           Corvus caurinus
# 1048557      Colaptes          Colaptes auratus
# 1048558   Zonotrichia    Zonotrichia leucophrys
# 1048559    Haemorhous      Haemorhous mexicanus
# 1048560    Cyanocitta       Cyanocitta stelleri
# 1048561     Setophaga        Setophaga coronata
# 1048562        Spinus              Spinus pinus
# 1048563     Melospiza         Melospiza melodia
# 1048564          Anas            Anas americana
# 1048565         Buteo         Buteo jamaicensis
# 1048566          Anas                Anas acuta
# 1048567          Anas        Anas platyrhynchos
# 1048568     Bucephala         Bucephala albeola
# 1048569         Ardea            Ardea herodias
# 1048570        Branta         Branta canadensis
# 1048571        Tringa        Tringa melanoleuca
# 1048572          Anas             Anas strepera
# 1048573   Zonotrichia   Zonotrichia atricapilla
# 1048574       Poecile      Poecile atricapillus
#
#                                ...                           taxonKey  \
# 0                              ...                                NaN
# 1                              ...                          2882758.0
# 2                              ...                          2512921.0
# 3                              ...                                NaN
# 4                              ...                                NaN
# 5                              ...                                NaN
# 6                              ...                                NaN
# 7                              ...                                NaN
# 8                              ...                          3189884.0
# 9                              ...                          3189884.0
# 10                             ...                          2685796.0
# 11                             ...                          3189866.0
# 12                             ...                                NaN
# 13                             ...                                NaN
# 14                             ...                          3189870.0
# 15                             ...                                NaN
# 16                             ...                                NaN
# 17                             ...                                NaN
# 18                             ...                          2888754.0
# 19                             ...                                NaN
# 20                             ...                                NaN
# 21                             ...                                NaN
# 22                             ...                          2685796.0
# 23                             ...                          2865368.0
# 24                             ...                          7696337.0
# 25                             ...                          3189864.0
# 26                             ...                          3189884.0
# 27                             ...                          3189884.0
# 28                             ...                                NaN
# 29                             ...                                NaN
# ...                            ...                                ...
# 1048545                        ...                                NaN
# 1048546                        ...                                NaN
# 1048547                        ...                                NaN
# 1048548                        ...                                NaN
# 1048549                        ...                                NaN
# 1048550                        ...                                NaN
# 1048551                        ...                                NaN
# 1048552                        ...                                NaN
# 1048553                        ...                                NaN
# 1048554                        ...                                NaN
# 1048555                        ...                                NaN
# 1048556                        ...                                NaN
# 1048557                        ...                                NaN
# 1048558                        ...                                NaN
# 1048559                        ...                                NaN
# 1048560                        ...                                NaN
# 1048561                        ...                                NaN
# 1048562                        ...                                NaN
# 1048563                        ...                                NaN
# 1048564                        ...                                NaN
# 1048565                        ...                                NaN
# 1048566                        ...                                NaN
# 1048567                        ...                                NaN
# 1048568                        ...                                NaN
# 1048569                        ...                                NaN
# 1048570                        ...                                NaN
# 1048571                        ...                                NaN
# 1048572                        ...                                NaN
# 1048573                        ...                                NaN
# 1048574                        ...                                NaN
#
#         speciesKey      basisOfRecord institutionCode  collectionCode  \
# 0              NaN                NaN             NaN             NaN
# 1        2882758.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 2        2512921.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 3              NaN                NaN             NaN             NaN
# 4              NaN                NaN             NaN             NaN
# 5              NaN                NaN             NaN             NaN
# 6              NaN                NaN             NaN             NaN
# 7              NaN                NaN             NaN             NaN
# 8        3189884.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 9        3189884.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 10       2685796.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 11       3189866.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 12             NaN                NaN             NaN             NaN
# 13             NaN                NaN             NaN             NaN
# 14       3189870.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 15             NaN                NaN             NaN             NaN
# 16             NaN                NaN             NaN             NaN
# 17             NaN                NaN             NaN             NaN
# 18       2888754.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 19             NaN                NaN             NaN             NaN
# 20             NaN                NaN             NaN             NaN
# 21             NaN                NaN             NaN             NaN
# 22       2685796.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 23       2865368.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 24       7696337.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 25       3189864.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 26       3189884.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 27       3189884.0  HUMAN_OBSERVATION     iNaturalist    Observations
# 28             NaN                NaN             NaN             NaN
# 29             NaN                NaN             NaN             NaN
# ...            ...                ...             ...             ...
# 1048545        NaN                NaN             NaN             NaN
# 1048546        NaN                NaN             NaN             NaN
# 1048547        NaN                NaN             NaN             NaN
# 1048548        NaN                NaN             NaN             NaN
# 1048549        NaN                NaN             NaN             NaN
# 1048550        NaN                NaN             NaN             NaN
# 1048551        NaN                NaN             NaN             NaN
# 1048552        NaN                NaN             NaN             NaN
# 1048553        NaN                NaN             NaN             NaN
# 1048554        NaN                NaN             NaN             NaN
# 1048555        NaN                NaN             NaN             NaN
# 1048556        NaN                NaN             NaN             NaN
# 1048557        NaN                NaN             NaN             NaN
# 1048558        NaN                NaN             NaN             NaN
# 1048559        NaN                NaN             NaN             NaN
# 1048560        NaN                NaN             NaN             NaN
# 1048561        NaN                NaN             NaN             NaN
# 1048562        NaN                NaN             NaN             NaN
# 1048563        NaN                NaN             NaN             NaN
# 1048564        NaN                NaN             NaN             NaN
# 1048565        NaN                NaN             NaN             NaN
# 1048566        NaN                NaN             NaN             NaN
# 1048567        NaN                NaN             NaN             NaN
# 1048568        NaN                NaN             NaN             NaN
# 1048569        NaN                NaN             NaN             NaN
# 1048570        NaN                NaN             NaN             NaN
# 1048571        NaN                NaN             NaN             NaN
# 1048572        NaN                NaN             NaN             NaN
# 1048573        NaN                NaN             NaN             NaN
# 1048574        NaN                NaN             NaN             NaN
#
#          catalogNumber  recordNumber     rightsHolder  establishmentMeans  \
# 0                  NaN           NaN              NaN                 NaN
# 1              1218584           NaN      Amelia Ryan                 NaN
# 2              1220290           NaN     Riley Pollom                 NaN
# 3                  NaN           NaN              NaN                 NaN
# 4                  NaN           NaN              NaN                 NaN
# 5                  NaN           NaN              NaN                 NaN
# 6                  NaN           NaN              NaN                 NaN
# 7                  NaN           NaN              NaN                 NaN
# 8             11976556           NaN          Melissa                 NaN
# 9             12079495           NaN          aisha14                 NaN
# 10            12268863           NaN           dumo11                 NaN
# 11            12595466           NaN  John D Reynolds                 NaN
# 12                 NaN           NaN              NaN                 NaN
# 13                 NaN           NaN              NaN                 NaN
# 14            13063800           NaN  John D Reynolds                 NaN
# 15                 NaN           NaN              NaN                 NaN
# 16                 NaN           NaN              NaN                 NaN
# 17                 NaN           NaN              NaN                 NaN
# 18            13970966           NaN    Colin Barrows                 NaN
# 19                 NaN           NaN              NaN                 NaN
# 20                 NaN           NaN              NaN                 NaN
# 21                 NaN           NaN              NaN                 NaN
# 22            16176549           NaN         Ben Keen                 NaN
# 23            16267759           NaN         citizen1                 NaN
# 24            16276540           NaN         Ben Keen                 NaN
# 25            16279335           NaN  John D Reynolds                 NaN
# 26            16279353           NaN  John D Reynolds                 NaN
# 27            16279354           NaN  John D Reynolds                 NaN
# 28                 NaN           NaN              NaN                 NaN
# 29                 NaN           NaN              NaN                 NaN
# ...                ...           ...              ...                 ...
# 1048545            NaN           NaN              NaN                 NaN
# 1048546            NaN           NaN              NaN                 NaN
# 1048547            NaN           NaN              NaN                 NaN
# 1048548            NaN           NaN              NaN                 NaN
# 1048549            NaN           NaN              NaN                 NaN
# 1048550            NaN           NaN              NaN                 NaN
# 1048551            NaN           NaN              NaN                 NaN
# 1048552            NaN           NaN              NaN                 NaN
# 1048553            NaN           NaN              NaN                 NaN
# 1048554            NaN           NaN              NaN                 NaN
# 1048555            NaN           NaN              NaN                 NaN
# 1048556            NaN           NaN              NaN                 NaN
# 1048557            NaN           NaN              NaN                 NaN
# 1048558            NaN           NaN              NaN                 NaN
# 1048559            NaN           NaN              NaN                 NaN
# 1048560            NaN           NaN              NaN                 NaN
# 1048561            NaN           NaN              NaN                 NaN
# 1048562            NaN           NaN              NaN                 NaN
# 1048563            NaN           NaN              NaN                 NaN
# 1048564            NaN           NaN              NaN                 NaN
# 1048565            NaN           NaN              NaN                 NaN
# 1048566            NaN           NaN              NaN                 NaN
# 1048567            NaN           NaN              NaN                 NaN
# 1048568            NaN           NaN              NaN                 NaN
# 1048569            NaN           NaN              NaN                 NaN
# 1048570            NaN           NaN              NaN                 NaN
# 1048571            NaN           NaN              NaN                 NaN
# 1048572            NaN           NaN              NaN                 NaN
# 1048573            NaN           NaN              NaN                 NaN
# 1048574            NaN           NaN              NaN                 NaN
#
#                                                      issue
# 0                                                      NaN
# 1                             GEODETIC_DATUM_ASSUMED_WGS84
# 2          COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8          COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 9          COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 10         COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 11         COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 12                                                     NaN
# 13                                                     NaN
# 14         COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                            GEODETIC_DATUM_ASSUMED_WGS84
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22         COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 23         COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 24       COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...
# 25         COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 26         COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 27         COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 1048545                                                NaN
# 1048546                                                NaN
# 1048547                                                NaN
# 1048548                                                NaN
# 1048549                                                NaN
# 1048550                                                NaN
# 1048551                                                NaN
# 1048552                                                NaN
# 1048553                                                NaN
# 1048554                                                NaN
# 1048555                                                NaN
# 1048556                                                NaN
# 1048557                                                NaN
# 1048558                                                NaN
# 1048559                                                NaN
# 1048560                                                NaN
# 1048561                                                NaN
# 1048562                                                NaN
# 1048563                                                NaN
# 1048564                                                NaN
# 1048565                                                NaN
# 1048566                                                NaN
# 1048567                                                NaN
# 1048568                                                NaN
# 1048569                                                NaN
# 1048570                                                NaN
# 1048571                                                NaN
# 1048572                                                NaN
# 1048573                                                NaN
# 1048574                                                NaN
#
# [1048575 rows x 29 columns]

# %%
df = df.drop(['gbifID', 'datasetKey', 'occurrenceID', 'publishingOrgKey', 'eventDate', 'day', 'month', 'year',
         'countryCode', 'recordedBy', 'institutionCode', 'basisOfRecord', 'collectionCode', 'recordNumber',
        'identifiedBy', 'dateIdentified', 'license', 'rightsHolder','typeStatus', 'lastInterpreted', 'mediaType',
        'issue'], 1)

# %%
df.columns
# Out:
# Index([u'gbifID', u'datasetKey', u'occurrenceID', u'kingdom', u'phylum',
#        u'class', u'order', u'family', u'genus', u'species',
#        u'infraspecificEpithet', u'taxonRank', u'scientificName', u'locality',
#        u'decimalLatitude', u'decimalLongitude',
#        u'coordinateUncertaintyInMeters', u'coordinatePrecision', u'elevation',
#        u'taxonKey', u'speciesKey', u'basisOfRecord', u'institutionCode',
#        u'collectionCode', u'catalogNumber', u'recordNumber', u'rightsHolder',
#        u'establishmentMeans', u'issue'],
#       dtype='object')

# %%
df.duplicated(subset=['kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species'], keep = False).value_counts()
# Out:
# True     1047656
# False        919
# dtype: int64

# %%
df.duplicated(subset=['scientificName'], keep = False).value_counts()
# Out:
# True     1047608
# False        967
# dtype: int64

# %%
df.duplicated(subset=['scientificName'], keep = False)
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
# 6           True
# 7           True
# 8           True
# 9           True
# 10          True
# 11         False
# 12          True
# 13          True
# 14          True
# 15          True
# 16          True
# 17          True
# 18         False
# 19          True
# 20         False
# 21          True
# 22          True
# 23          True
# 24          True
# 25         False
# 26          True
# 27          True
# 28          True
# 29          True
#            ...
# 1048545     True
# 1048546     True
# 1048547     True
# 1048548     True
# 1048549     True
# 1048550     True
# 1048551     True
# 1048552     True
# 1048553     True
# 1048554     True
# 1048555     True
# 1048556     True
# 1048557     True
# 1048558     True
# 1048559     True
# 1048560     True
# 1048561     True
# 1048562     True
# 1048563     True
# 1048564     True
# 1048565     True
# 1048566     True
# 1048567     True
# 1048568     True
# 1048569     True
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# dtype: bool

# %%
df.values[10]
# Out:
# array([1913654554, '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#        'https://www.inaturalist.org/observations/12268863', 'Plantae',
#        'Tracheophyta', 'Pinopsida', 'Pinales', 'Pinaceae', 'Pseudotsuga',
#        'Pseudotsuga menziesii', nan, 'SPECIES',
#        'Pseudotsuga menziesii (Mirb.) Franco', nan, 49.442859000000006,
#        -123.33762, 4.0, nan, nan, 2685796.0, 2685796.0,
#        'HUMAN_OBSERVATION', 'iNaturalist', 'Observations', '12268863', nan,
#        'dumo11', nan, 'COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84'], dtype=object)

# %%
df.values[11]
# Out:
# array([1913654814, '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#        'https://www.inaturalist.org/observations/12595466', 'Plantae',
#        'Tracheophyta', 'Magnoliopsida', 'Sapindales', 'Sapindaceae',
#        'Acer', 'Acer negundo', nan, 'SPECIES', 'Acer negundo L.', nan,
#        49.231752, -122.80846000000001, nan, nan, nan, 3189866.0, 3189866.0,
#        'HUMAN_OBSERVATION', 'iNaturalist', 'Observations', '12595466', nan,
#        'John D Reynolds', nan,
#        'COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84'], dtype=object)

# %%
df.scientificName
# Out:
# 0                      Syngnathus leptorhynchus Girard
# 1                             Gaultheria shallon Pursh
# 2          Dacrymyces chrysospermus Berk. & M.A.Curtis
# 3                          Branta canadensis (Linnaeus
# 4                          Anas platyrhynchos Linnaeus
# 5                      Lophodytes cucullatus (Linnaeus
# 6                          Melospiza melodia (A.Wilson
# 7                                 Larus canus Linnaeus
# 8                                Acer circinatum Pursh
# 9                                Acer circinatum Pursh
# 10                Pseudotsuga menziesii (Mirb.) Franco
# 11                                     Acer negundo L.
# 12                   Coccinella californica Mannerheim
# 13                       Lithobates catesbeianus (Shaw
# 14                              Acer pseudoplatanus L.
# 15                          Chrysemys picta (Schneider
# 16             Trachemys scripta (Thunberg In Schoepff
# 17             Trachemys scripta (Thunberg In Schoepff
# 18                          Valeriana sitchensis Bong.
# 19                            Noctua pronuba (Linnaeus
# 20                      Urocerus albicornis (Fabricius
# 21                            Dargida procinctus Grote
# 22                Pseudotsuga menziesii (Mirb.) Franco
# 23                              Triglochin maritima L.
# 24                          Nuphar polysepalum Engelm.
# 25                                  Acer glabrum Torr.
# 26                               Acer circinatum Pursh
# 27                               Acer circinatum Pursh
# 28          Ensatina eschscholtzii oregonensis (Girard
# 29                           Araneus diadematus Clerck
#                               ...
# 1048545                      Pipilo maculatus Swainson
# 1048546                   Setophaga coronata (Linnaeus
# 1048547               Tachycineta thalassina (Swainson
# 1048548                        Junco hyemalis Linnaeus
# 1048549             Streptopelia decaocto (Frivaldszky
# 1048550                        Ardea herodias Linnaeus
# 1048551                          Corvus corax Linnaeus
# 1048552                 Poecile atricapillus (Linnaeus
# 1048553                  Dryobates pubescens (Linnaeus
# 1048554                    Turdus migratorius Linnaeus
# 1048555            Zonotrichia atricapilla (J.F.Gmelin
# 1048556                      Corvus caurinus S.F.Baird
# 1048557                     Colaptes auratus (Linnaeus
# 1048558            Zonotrichia leucophrys (J.R.Forster
# 1048559       Haemorhous mexicanus (P.L.Statius Müller
# 1048560                    Cyanocitta stelleri (Gmelin
# 1048561                   Setophaga coronata (Linnaeus
# 1048562                         Spinus pinus (A.Wilson
# 1048563                    Melospiza melodia (A.Wilson
# 1048564                       Mareca americana (Gmelin
# 1048565                      Buteo jamaicensis (Gmelin
# 1048566                            Anas acuta Linnaeus
# 1048567                    Anas platyrhynchos Linnaeus
# 1048568                    Bucephala albeola (Linnaeus
# 1048569                        Ardea herodias Linnaeus
# 1048570                    Branta canadensis (Linnaeus
# 1048571                     Tringa melanoleuca (Gmelin
# 1048572                      Mareca strepera (Linnaeus
# 1048573            Zonotrichia atricapilla (J.F.Gmelin
# 1048574                 Poecile atricapillus (Linnaeus
# Name: scientificName, dtype: object

# %%
duplicated_groups = df.groupby('scientificName')

# %%
duplicated_groups.get_group('Abies grandis Lindl.')
# Out:
#             basisOfRecord catalogNumber      class collectionCode  \
# 34970   HUMAN_OBSERVATION       7473269  Pinopsida   Observations
# 107699  HUMAN_OBSERVATION       9678500  Pinopsida   Observations
# 431761  HUMAN_OBSERVATION      18346223  Pinopsida   Observations
#
#         coordinatePrecision  coordinateUncertaintyInMeters  \
# 34970                   NaN                           10.0
# 107699                  NaN                            NaN
# 431761                  NaN                            5.0
#
#                                   datasetKey  decimalLatitude  \
# 34970   50c9509d-22c7-4a22-a47d-8c48425ef4a7        49.304448
# 107699  50c9509d-22c7-4a22-a47d-8c48425ef4a7        49.193458
# 431761  50c9509d-22c7-4a22-a47d-8c48425ef4a7        49.303361
#
#         decimalLongitude  elevation    ...    locality  \
# 34970        -123.132424        NaN    ...         NaN
# 107699       -123.171647        NaN    ...         NaN
# 431761       -123.136306        NaN    ...         NaN
#
#                                              occurrenceID    order  \
# 34970          http://inaturalist.ca/observations/7473269  Pinales
# 107699   https://www.inaturalist.org/observations/9678500  Pinales
# 431761  https://www.inaturalist.org/observations/18346223  Pinales
#
#               phylum recordNumber                rightsHolder        species  \
# 34970   Tracheophyta          NaN                       esle9  Abies grandis
# 107699  Tracheophyta          NaN  miscellaneous_observations  Abies grandis
# 431761  Tracheophyta          NaN             John D Reynolds  Abies grandis
#
#        speciesKey   taxonKey taxonRank
# 34970   2685361.0  2685361.0   SPECIES
# 107699  2685361.0  2685361.0   SPECIES
# 431761  2685361.0  2685361.0   SPECIES
#
# [3 rows x 28 columns]

# %%
df
# Out:
# False
